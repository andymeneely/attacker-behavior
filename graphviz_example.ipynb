# %%
from graphviz import Digraph

dot1 = Digraph(comment = "Unauthenticated Postgres Remote Access")

dot1.node("A", "Network Service Scanning")
dot1.node("B", "Pre-Attack")
dot1.node("C", "Network Service Scanning, Credentials in Files")
dot1.node("D", "Brute Force Valid Accounts, Remote Services")

dot1.edge("A", "B", label="0.00381%/sec")
dot1.edge("A", "C", label="0.0991%/sec")
dot1.edge("A", "D", label="0.152%/sec")
dot1.edge("B", "D", label="0.794%/sec")
dot1.edge("C", "D", label="0.00809%/sec")

# %%
dot1

# %%
dot1.attr(rankdir="LR")

# %%
dot1

# %%
dot1 = Digraph(comment = "Unauthenticated Postgres Remote Access")

dot1.attr("node", shape="box")
dot1.attr(rankdir="LR")
dot1.attr(splines="polyline")

dot1.node("A", "Network Service Scanning", style="filled", fillcolor="#B4CDCD", color="blue")
dot1.node("B", "Pre-Attack", style="filled", fillcolor="#EEE9E9")
dot1.node("C", "Network Service Scanning, Credentials in Files", style="filled", fillcolor="#EEE9E9")
dot1.node("D", "Brute Force Valid Accounts, Remote Services", style="filled", fillcolor="#ECC3BF", color="red")

dot1.edge("A", "B", label="0.00381%/sec")
dot1.edge("A", "C", label="0.0991%/sec")
dot1.edge("A", "D", label="0.152%/sec")
dot1.edge("B", "D", label="0.794%/sec")
dot1.edge("C", "D", label="0.00809%/sec")

# %%
dot1
